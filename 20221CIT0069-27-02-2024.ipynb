# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
df =  pd.read_csv('/Datasets/BL-Flickr-Images-Book.csv')
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 3  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 4  [The World in which I live, and my place in it...  A., E. S.
#
#                                    Contributors  Corporate Author  \
# 0                               FORBES, Walter.               NaN
# 1  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                   Appleyard, Ernest Silvanus.               NaN
# 4                           BROOME, John Henry.               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
# 2                     NaN          NaN       NaN   monographic
# 3                     NaN          NaN       NaN   monographic
# 4                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Identifier'].plot(kind='hist', bins=20, title='Identifier')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Edition Statement').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Place of Publication').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Date of Publication').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Publisher').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Edition Statement')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Edition Statement', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Place of Publication')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Place of Publication', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date of Publication')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date of Publication', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Publisher')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Publisher', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['Identifier'].plot(kind='line', figsize=(8, 4), title='Identifier')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Place of Publication'].value_counts()
#     for x_label, grp in _df_10.groupby('Edition Statement')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Edition Statement')
# _ = plt.ylabel('Place of Publication')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Date of Publication'].value_counts()
#     for x_label, grp in _df_11.groupby('Place of Publication')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Place of Publication')
# _ = plt.ylabel('Date of Publication')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Publisher'].value_counts()
#     for x_label, grp in _df_12.groupby('Date of Publication')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Date of Publication')
# _ = plt.ylabel('Publisher')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Title'].value_counts()
#     for x_label, grp in _df_13.groupby('Publisher')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Publisher')
# _ = plt.ylabel('Title')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Edition Statement'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='Identifier', y='Edition Statement', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Place of Publication'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='Identifier', y='Place of Publication', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['Date of Publication'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='Identifier', y='Date of Publication', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Publisher'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Identifier', y='Publisher', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
to_drop = ['Edition Statement']

# %%
df =  pd.read_csv('/Datasets/BL-Flickr-Images-Book.csv')
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 3  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 4  [The World in which I live, and my place in it...  A., E. S.
#
#                                    Contributors  Corporate Author  \
# 0                               FORBES, Walter.               NaN
# 1  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                   Appleyard, Ernest Silvanus.               NaN
# 4                           BROOME, John Henry.               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
# 2                     NaN          NaN       NaN   monographic
# 3                     NaN          NaN       NaN   monographic
# 4                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['Identifier'].plot(kind='hist', bins=20, title='Identifier')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_19.groupby('Edition Statement').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_20.groupby('Place of Publication').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_21.groupby('Date of Publication').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_22.groupby('Publisher').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Edition Statement')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Edition Statement', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_24.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Place of Publication')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Place of Publication', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_25.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date of Publication')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date of Publication', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Identifier']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Identifier'}, axis=1)
#               .sort_values('Identifier', ascending=True))
#   xs = counted['Identifier']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_26.sort_values('Identifier', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Publisher')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Publisher', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Identifier')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['Identifier'].plot(kind='line', figsize=(8, 4), title='Identifier')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Place of Publication'].value_counts()
#     for x_label, grp in _df_28.groupby('Edition Statement')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Edition Statement')
# _ = plt.ylabel('Place of Publication')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Date of Publication'].value_counts()
#     for x_label, grp in _df_29.groupby('Place of Publication')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Place of Publication')
# _ = plt.ylabel('Date of Publication')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Publisher'].value_counts()
#     for x_label, grp in _df_30.groupby('Date of Publication')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Date of Publication')
# _ = plt.ylabel('Publisher')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Title'].value_counts()
#     for x_label, grp in _df_31.groupby('Publisher')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Publisher')
# _ = plt.ylabel('Title')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_32['Edition Statement'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_32, x='Identifier', y='Edition Statement', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_33['Place of Publication'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_33, x='Identifier', y='Place of Publication', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_34['Date of Publication'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_34, x='Identifier', y='Date of Publication', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_35['Publisher'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_35, x='Identifier', y='Publisher', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
to_drop = ['Edition Statement','Shelfmarks']
df.drop(to_drop,inplace=True,axis=1)
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3  A., E. S.                   Appleyard, Ernest Silvanus.               NaN
# 4  A., E. S.                           BROOME, John Henry.               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
# 2                     NaN          NaN       NaN   monographic
# 3                     NaN          NaN       NaN   monographic
# 4                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...

# %%
df['Date of Publication'].head(25)
# Out:
# 0            1879 [1878]
# 1                   1868
# 2                   1869
# 3                   1851
# 4                   1857
# 5                   1875
# 6                   1872
# 7                    NaN
# 8                   1676
# 9                   1679
# 10                  1802
# 11                  1859
# 12                  1888
# 13           1839, 38-54
# 14                  1897
# 15                  1865
# 16               1860-63
# 17                  1873
# 18                  1866
# 19                  1899
# 20                  1814
# 21                  1820
# 22                  1800
# 23    1847, 48 [1846-48]
# 24               [1897?]
# Name: Date of Publication, dtype: object

# %%
df['Title'].head(25)
# Out:
# 0                     Walter Forbes. [A novel.] By A. A
# 1     All for Greed. [A novel. The dedication signed...
# 2     Love the Avenger. By the author of “All for Gr...
# 3     Welsh Sketches, chiefly ecclesiastical, to the...
# 4     [The World in which I live, and my place in it...
# 5     [The World in which I live, and my place in it...
# 6     Lagonells. By the author of Darmayne (F. E. A....
# 7     The Coming of Spring, and other poems. By J. A...
# 8     A Warning to the inhabitants of England, and L...
# 9     A Satyr against Vertue. (A poem: supposed to b...
# 10    An Account of the many and great Loans, Benefa...
# 11    Erindringer som Bidrag til Norges Historie fra...
# 12    Gli Studi storici in terra d'Otranto ... Framm...
# 13    De Aardbol. Magazijn van hedendaagsche land- e...
# 14    Cronache Savonesi dal 1500 al 1570 ... Accresc...
# 15    See-Saw; a novel ... Edited [or rather, writte...
# 16    Géodésie d'une partie de la Haute Éthiopie,...
# 17                                  [With eleven maps.]
# 18    [Historia geográfica, civil y politica de la ...
# 19    The Crisis of the Revolution, being the story ...
# 20    Peace: a lyric poem. [With prefatory address b...
# 21    Abdallah; or, The Arabian Martyr: a Christian ...
# 22    [Abdollatiphi Historiæ Ægypti compendium. [Wit...
# 23    The Comic History of England ... With ... colo...
# 24    [The comic history of England ... With twenty ...
# Name: Title, dtype: object

# %%
df['Publisher'].head(69)
# Out:
# 0                   S. Tinsley & Co.
# 1                       Virtue & Co.
# 2              Bradbury, Evans & Co.
# 3                      James Darling
# 4               Wertheim & Macintosh
#                    ...
# 64                               NaN
# 65                               NaN
# 66    Ticknor & Fields; J. R. Osgood
# 67                               NaN
# 68                    Chapman & Hall
# Name: Publisher, Length: 69, dtype: object
